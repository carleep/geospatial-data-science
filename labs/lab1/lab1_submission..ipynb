# %%
import numpy as np
a = 3
b = 2
c = a + b
d = np.multiply(a, c)
e = np.multiply(b, c)
f = np.multiply(a,b)
print(d, e, f)

# %% [markdown]
# ![silverfalls.jpg](attachment:silverfalls.jpg)
# [Portland Travel](https://www.travelportland.com/region/silver-falls-state-park/)<br>
# This is a picture of the **Silver Falls State Park**. It many focus is on the waterfall where you can *walk behind* the waterfall.
